# %% [markdown]
# <a href="https://colab.research.google.com/github/klinkzsweet/PCVK_Genap_2023/blob/main/TaskWeek2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

#Accessing My Goole Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

img = cv.imread('/content/drive/MyDrive/PCVK/images/sample kucing.jpg')
plt.imshow(img) #perhatikan hasilnya adalah citra dgn channel

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB) #konversi channel BGR -> RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/images/sample kucing.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#simpan file image
#cv.imwrite('/content/drive/MyDrive/PCVK/images/sample kucing.jpg',img5)

#tampilkan plot dengan ukuran canvas yg lebih besar
fig = plt.figure(figsize=(10,10))   #ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik2 pt1 dan pt2
#cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
tinggi = black_img.shape[0]
lebar = black_img.shape[1]

line_start = (int(lebar/4), int(tinggi/4))
line_end = (int(3 * lebar/6), int(3*tinggi/6))
color = (0, 255, 0)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
tinggi = black_img.shape[0]
lebar = black_img.shape[1]

cv.circle(black_img,center=(400,400),radius=60,color=(255,0,0),thickness=-1)
for x in range (tinggi):
  black_img[x, int(x*(lebar/tinggi))] = [255,255,255]
#cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# Tugas

# %%
img = cv.imread('/content/drive/MyDrive/PCVK/images/965105.jpg')
b,g,r = cv.split(img)
img[:, :, 2],[:, :, 1],[:, :, 0] = cv.split
img_rb = cv.merge((b,g*0,r))

plt.imshow(img_rb)

# %%
b,g,r = cv.split(img)
img_rb = cv.merge((r*0,g,b))
plt.imshow(img_rb)

# %%
img_k = img[20:115,25:120]
plt.imshow(img_k)

# %%
img = cv.imread('/content/drive/MyDrive/PCVK/images/965105.jpg')
plt.imshow(img[5:30], cmap='Reds')

# %%
img = cv.imread('/content/drive/MyDrive/PCVK/images/sample kucing.jpg')

imageWithRectangle = img

fig = plt.figure(figsize=(10,10))
cv.rectangle(imageWithRectangle, pt1=(400,200), pt2=(200,50), color=(0,255, 255), thickness = 15)
cv.rectangle(imageWithRectangle, pt1=(500,250), pt2=(250,100), color=(0,255,0), thickness = 10)
cv.rectangle(imageWithRectangle, pt1=(800,150), pt2=(300,300), color=(255,255,255), thickness = 10)
cv.rectangle(imageWithRectangle, pt1=(200,150), pt2=(100,200), color=(255,0,0), thickness = 10)
cv.rectangle(imageWithRectangle, pt1=(300,200), pt2=(150,120), color=(0,0,255),thickness= 7)

plt.imshow(imageWithRectangle)

# %%
imageWithRectangle = cv.flip(cv.cvtColor(imageWithRectangle,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(9,9))
ax = fig.add_subplot(111)
ax.imshow(imageWithRectangle)

# %%
img = cv.imread('/content/drive/MyDrive/PCVK/images/sample kucing.jpg')
fig = plt.figure(figsize=(5,5))

ax = fig.add_subplot(111)
cv.rectangle(img, pt1=(300,120), pt2=(500,280), color=(255, 0, 30), thickness = 10)
cv.circle(img, center=(400, 200), radius=150, color=(180, 105, 255), thickness = 10)
ax.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))

# %%
img = cv.imread('/content/drive/MyDrive/PCVK/images/sample kucing.jpg')

cv.rectangle(img, pt1=(10,400), pt2 = (250,600), color= (0,0,255), thickness=20)

plt.imshow(img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(img, text='Hello', org=(2,550),fontFace=font,fontScale=3,color=(255,255,0),thickness=5,lineType=cv.LINE_AA)
plt.imshow(img)
